# %%
import pandas as pd
import numpy as np

# %%
# !ls
# Out:
# Untitled.ipynb
# assignment4.R
# comflight.xlsx

# %%
testing = pd.read_excel("comflight.xlsx", sheet_name=0, skiprows=range(5), header=None, columns=['airport', 'number']).dropna()

# %%
testing.columns = ['airport', 'number']

# %%
testing
# Out:
#                                               airport    number
# 0                                                KLIA  325537.0
# 1                                       PULAU PINANG    56760.0
# 2                                       KOTA KINABALU   67600.9
# 3                                             KUCHING   53095.0
# 4                                            LANGKAWI   17675.0
# 5                                         JOHOR BHARU   37998.0
# 6                                          KOTA BHARU   20527.0
# 7                                                IPOH    1464.0
# 8                                    KUALA TERENGGANU    7365.0
# 9                                          ALOR SETAR    5795.0
# 10                                             MELAKA     580.0
# 11                                             SUBANG   41707.0
# 12                                            KUANTAN    3289.0
# 13                                             TIOMAN    1538.0
# ...
